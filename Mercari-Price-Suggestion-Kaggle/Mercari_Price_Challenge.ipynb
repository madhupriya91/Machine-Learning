# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Data Study
df=pd.read_table('C:\Madhu\DataSets\Kaggle\Mercari_Price_Sugg\\train.tsv','\t')
print df.columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 593376 entries, 0 to 593375
# Data columns (total 8 columns):
# train_id             593376 non-null int64
# name                 593376 non-null object
# item_condition_id    593376 non-null int64
# category_name        590835 non-null object
# brand_name           340359 non-null object
# price                593376 non-null float64
# shipping             593376 non-null int64
# item_description     593375 non-null object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 36.2+ MB

# %%
df.name.value_counts(dropna=False)
# Out:
# Bundle                                      901
# Reserved                                    180
# BUNDLE                                      172
# Converse                                    165
# Dress                                       163
# Coach purse                                 149
# Lularoe TC leggings                         144
# Nike                                        141
# American Eagle Jeans                        133
# Vans                                        132
# Romper                                      130
# Miss Me Jeans                               120
# Lularoe OS leggings                         119
# ON HOLD                                     114
# Shorts                                      113
# Coach Purse                                 109
# Lularoe Irma                                106
# Bundle!                                     105
# Coach wallet                                102
# Michael Kors Purse                           97
# ...

# %%
df.item_condition_id.value_counts(dropna=False)
# Out:
# 1    256121
# 3    172980
# 2    150564
# 4     12738
# 5       973
# Name: item_condition_id, dtype: int64

# %%
df.brand_name.value_counts(dropna=False)
# Out:
# NaN                     253017
# PINK                     21667
# Nike                     21336
# Victoria's Secret        19370
# LuLaRoe                  12410
# Apple                     6922
# Nintendo                  6112
# FOREVER 21                6007
# Lululemon                 5802
# Michael Kors              5587
# American Eagle            5311
# Rae Dunn                  4995
# Sephora                   4868
# Coach                     4211
# Adidas                    4190
# Bath & Body Works         4141
# Disney                    4089
# Funko                     3754
# Under Armour              3338
# Sony                      3263
# Old Navy                  3134
# Hollister                 2759
# Carter's                  2620
# Urban Decay               2513
# The North Face            2420
# Too Faced                 2324
# Xbox                      2290
# Independent               2284
# MAC                       2217
# Brandy Melville           2200
# ...

# %%
df.shipping.value_counts(dropna=False)
# Out:
# 0    328556
# 1    264820
# Name: shipping, dtype: int64

# %%
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# train_id                  0
# name                      0
# item_condition_id         0
# category_name          2541
# brand_name           253017
# price                     0
# shipping                  0
# item_description          1
# dtype: int64

# %%
df['category_name'].value_counts()[:5]
# Out:
# Women/Athletic Apparel/Pants, Tights, Leggings    23840
# Women/Tops & Blouses/T-Shirts                     18570
# Beauty/Makeup/Face                                13731
# Beauty/Makeup/Lips                                11878
# Electronics/Video Games & Consoles/Games          10644
# Name: category_name, dtype: int64

# %%
df['brand_name'].value_counts()[:5]
# Out:
# PINK                 21667
# Nike                 21336
# Victoria's Secret    19370
# LuLaRoe              12410
# Apple                 6922
# Name: brand_name, dtype: int64

# %%
df['name'].value_counts()[:5]
# Out:
# Bundle      901
# Reserved    180
# BUNDLE      172
# Converse    165
# Dress       163
# Name: name, dtype: int64

# %%
dataPINK=df.brand_name=='PINK'

# %%
df[dataPINK]
# Out:
#         train_id                                      name  item_condition_id  \
# 0              0       MLB Cincinnati Reds T Shirt Size XL                  3
# 1              1          Razer BlackWidow Chroma Keyboard                  3
# 2              2                            AVA-VIV Blouse                  1
# 3              3                     Leather Horse Statues                  1
# 4              4                      24K GOLD plated rose                  1
# 5              5          Bundled items requested for Ruie                  3
# 6              6        Acacia pacific tides santorini top                  3
# 7              7      Girls cheer and tumbling bundle of 7                  3
# 8              8                     Girls Nike Pro shorts                  3
# 9              9    Porcelain clown doll checker pants VTG                  3
# 10            10                           Smashbox primer                  2
# ...

# %%
df[dataPINK].head()
# Out:
#    train_id                                 name  item_condition_id  \
# 0         0  MLB Cincinnati Reds T Shirt Size XL                  3
# 1         1     Razer BlackWidow Chroma Keyboard                  3
# 2         2                       AVA-VIV Blouse                  1
# 3         3                Leather Horse Statues                  1
# 4         4                 24K GOLD plated rose                  1
#
#                                        category_name brand_name  price  \
# 0                                  Men/Tops/T-shirts       PINK   10.0
# 1  Electronics/Computers & Tablets/Components & P...       PINK   52.0
# 2                        Women/Tops & Blouses/Blouse       PINK   10.0
# 3                 Home/Home Décor/Home Décor Accents       PINK   35.0
# 4                            Women/Jewelry/Necklaces       PINK   44.0
#
#    shipping                                   item_description
# 0         1                                 No description yet
# ...

# %%
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# train_id                0
# name                    0
# item_condition_id       0
# category_name        2541
# brand_name              0
# price                   0
# shipping                0
# item_description        1
# dtype: int64

# %%
df['brand_name']
# Out:
# 0         PINK
# 1         PINK
# 2         PINK
# 3         PINK
# 4         PINK
# 5         PINK
# 6         PINK
# 7         PINK
# 8         PINK
# 9         PINK
# 10        PINK
# 11        PINK
# 12        PINK
# 13        PINK
# 14        PINK
# 15        PINK
# 16        PINK
# 17        PINK
# 18        PINK
# 19        PINK
# 20        PINK
# 21        PINK
# 22        PINK
# 23        PINK
# 24        PINK
# 25        PINK
# 26        PINK
# 27        PINK
# 28        PINK
# 29        PINK
#           ...
# 593346    PINK
# 593347    PINK
# 593348    PINK
# 593349    PINK
# 593350    PINK
# 593351    PINK
# 593352    PINK
# 593353    PINK
# 593354    PINK
# 593355    PINK
# 593356    PINK
# 593357    PINK
# 593358    PINK
# 593359    PINK
# 593360    PINK
# 593361    PINK
# 593362    PINK
# 593363    PINK
# 593364    PINK
# 593365    PINK
# 593366    PINK
# 593367    PINK
# 593368    PINK
# 593369    PINK
# 593370    PINK
# 593371    PINK
# 593372    PINK
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 593376 entries, 0 to 593375
# Data columns (total 8 columns):
# train_id             593376 non-null int64
# name                 593376 non-null object
# item_condition_id    593376 non-null int64
# category_name        590835 non-null object
# brand_name           593376 non-null object
# price                593376 non-null float64
# shipping             593376 non-null int64
# item_description     593375 non-null object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 36.2+ MB

# %%
df['brand_name'].value_counts()
# Out:
# PINK    593376
# Name: brand_name, dtype: int64

# %% [raw]
# df.describe()

# %%
# Data Study
df=pd.read_table('C:\Madhu\DataSets\Kaggle\Mercari_Price_Sugg\\train.tsv','\t')
print df.columns
# Out:
# Index([u'train_id', u'name', u'item_condition_id', u'category_name',
#        u'brand_name', u'price', u'shipping', u'item_description'],
#       dtype='object')

# %%
df.brand_name.value_counts()
# Out:
# PINK                      21667
# Nike                      21336
# Victoria's Secret         19370
# LuLaRoe                   12410
# Apple                      6922
# Nintendo                   6112
# FOREVER 21                 6007
# Lululemon                  5802
# Michael Kors               5587
# American Eagle             5311
# Rae Dunn                   4995
# Sephora                    4868
# Coach                      4211
# Adidas                     4190
# Bath & Body Works          4141
# Disney                     4089
# Funko                      3754
# Under Armour               3338
# Sony                       3263
# Old Navy                   3134
# Hollister                  2759
# Carter's                   2620
# Urban Decay                2513
# The North Face             2420
# Too Faced                  2324
# Xbox                       2290
# Independent                2284
# MAC                        2217
# Brandy Melville            2200
# ...

# %%
dataPINK=df.loc[df.brand_name=='PINK']
dataPINK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21667 entries, 32 to 593351
# Data columns (total 8 columns):
# train_id             21667 non-null int64
# name                 21667 non-null object
# item_condition_id    21667 non-null int64
# category_name        21602 non-null object
# brand_name           21667 non-null object
# price                21667 non-null float64
# shipping             21667 non-null int64
# item_description     21667 non-null object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 1.5+ MB

# %%
dataPINK['brand_name'].value_counts()
# Out:
# PINK    21667
# Name: brand_name, dtype: int64

# %%
df['brand_name'].value_counts()
# Out:
# PINK                      21667
# Nike                      21336
# Victoria's Secret         19370
# LuLaRoe                   12410
# Apple                      6922
# Nintendo                   6112
# FOREVER 21                 6007
# Lululemon                  5802
# Michael Kors               5587
# American Eagle             5311
# Rae Dunn                   4995
# Sephora                    4868
# Coach                      4211
# Adidas                     4190
# Bath & Body Works          4141
# Disney                     4089
# Funko                      3754
# Under Armour               3338
# Sony                       3263
# Old Navy                   3134
# Hollister                  2759
# Carter's                   2620
# Urban Decay                2513
# The North Face             2420
# Too Faced                  2324
# Xbox                       2290
# Independent                2284
# MAC                        2217
# Brandy Melville            2200
# ...

# %%
def split_cat(text):
    try: return text.split("/")
    except: return ("No Label", "No Label", "No Label")


df['general_cat'],df['sub_cat1'],df['sub_cat2']= zip(*df['category_name'].apply(lambda x: split_cat(x)))
df.head()

# %%
dataMen=df[df['general_cat']=='Men']
dataMen.brand_name.value_counts()
# Out:
# Nike                         5522
# Adidas                       1752
# Polo Ralph Lauren            1382
# Air Jordan                   1354
# Under Armour                  946
# Jordan                        683
# VANS                          634
# American Eagle                513
# The North Face                447
# Supreme                       427
# Tommy Hilfiger                373
# PINK                          348
# Levi's®                       325
# Hollister                     314
# Gucci                         303
# True Religion Brand Jeans     285
# vineyard vines                251
# Converse                      238
# Reebok                        233
# Oakley                        211
# Hot Topic                     208
# New Era                       207
# patagonia                     195
# Timberland                    186
# H&M                           181
# Columbia                      178
# Champion                      178
# ...

# %%
df
# Out:
#         train_id                                      name  item_condition_id  \
# 0              0       MLB Cincinnati Reds T Shirt Size XL                  3
# 1              1          Razer BlackWidow Chroma Keyboard                  3
# 2              2                            AVA-VIV Blouse                  1
# 3              3                     Leather Horse Statues                  1
# 4              4                      24K GOLD plated rose                  1
# 5              5          Bundled items requested for Ruie                  3
# 6              6        Acacia pacific tides santorini top                  3
# 7              7      Girls cheer and tumbling bundle of 7                  3
# 8              8                     Girls Nike Pro shorts                  3
# 9              9    Porcelain clown doll checker pants VTG                  3
# 10            10                           Smashbox primer                  2
# ...

# %%
#Top five women's brands
dataWomen.brand_name.value_counts()[:5]
# Out:
# PINK                 21093
# Victoria's Secret    15715
# LuLaRoe              12299
# Nike                  9765
# FOREVER 21            5791
# Name: brand_name, dtype: int64

# %%
#Top five men's brands
dataMen.brand_name.value_counts()[:5]
# Out:
# Nike                 5522
# Adidas               1752
# Polo Ralph Lauren    1382
# Air Jordan           1354
# Under Armour          946
# Name: brand_name, dtype: int64

# %%
menMostExpensive = dataMen.sort_values('price',ascending=False)
womenMostExpensive = dataWomen.sort_values('price', ascending=False)

# %%
#Top five most expensive men's brands
menMostExpensive['brand_name'].value_counts()[:5]
# Out:
# Nike                 5522
# Adidas               1752
# Polo Ralph Lauren    1382
# Air Jordan           1354
# Under Armour          946
# Name: brand_name, dtype: int64

# %%
#Top five most expensive women's brands
womenMostExpensive['brand_name'].value_counts()[:5]
# Out:
# PINK                 21093
# Victoria's Secret    15715
# LuLaRoe              12299
# Nike                  9765
# FOREVER 21            5791
# Name: brand_name, dtype: int64

# %%
#Top five most expensive men's product names
menMostExpensive['name'].value_counts()[:5]
# Out:
# Nike                                        31
# 14K YELLOW GOLD FINISHED NECKLACES COMBO    30
# Vans                                        29
# Adidas                                      24
# Bundle                                      23
# Name: name, dtype: int64

# %%
#Top five most expensive women's product names
womenMostExpensive['name'].value_counts()[:5]
# Out:
# Bundle                  492
# Dress                   152
# Lularoe TC leggings     143
# Romper                  128
# American Eagle Jeans    126
# Name: name, dtype: int64

# %%
#Top five genereal categories

df.general_cat.value_counts()[:5]
# Out:
# Women          265870
# Beauty          83315
# Kids            68404
# Electronics     49173
# Men             37508
# Name: general_cat, dtype: int64

# %%
# Top five beauty brands
df[df.general_cat=='Beauty'].brand_name.value_counts()[:5]
# Out:
# Sephora              4863
# Bath & Body Works    3622
# Victoria's Secret    3498
# Urban Decay          2505
# Too Faced            2321
# Name: brand_name, dtype: int64

# %%
# Top five kids brands
df[df.general_cat=='Kids'].brand_name.value_counts()[:5]
# Out:
# Nike        5182
# Carter's    2617
# Funko       2427
# Disney      2239
# Gap         1356
# Name: brand_name, dtype: int64

# %%
# Top five electronic brands
df[df.general_cat=='Electronics'].brand_name.value_counts()[:5]
# Out:
# Apple       6897
# Nintendo    5557
# Sony        3076
# Xbox        2154
# Samsung     1611
# Name: brand_name, dtype: int64

# %%
df.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# train_id                  0
# name                      0
# item_condition_id         0
# category_name          2541
# brand_name           253017
# price                     0
# shipping                  0
# item_description          1
# general_cat               0
# sub_cat1                  0
# sub_cat2                  0
# dtype: int64

# %%
# Price distribution
plt.figure(figsize=(20, 15))
plt.hist(df['price'], bins=50, range=[0,250], label='price')
plt.title('Train "price" distribution', fontsize=15)
plt.xlabel('Price', fontsize=15)
plt.ylabel('Number', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(fontsize=15)
plt.show()

# %%
#plt.figure(figsize=(50, 20))
plt.boxplot(df['price'])
plt.ylim(0, 60)
plt.show()

# %%
df.boxplot(column='price',by='item_condition_id')
plt.ylim(0, 80)
plt.show()

# %%
# Price distribution
plt.figure(figsize=(20, 15))
plt.hist(df['item_condition_id'], bins=50, range=[0,6], label='item_condition_id')
#plt.title('Train "price" distribution', fontsize=15)
plt.xlabel('item_condition_id', fontsize=15)
plt.ylabel('Number', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(fontsize=15)
plt.show()

# %%
df.boxplot(column='price',by='shipping')
plt.ylim(0, 80)
plt.show()

# %%
df.general_cat.value_counts()

# %%
plt.figure(figsize=(20, 10))
sns.violinplot(x='general_cat',y='price',data=df)
plt.ylim(-30, 100)
#plt.xlim(0,13)
plt.xticks(fontsize=15,style='oblique')
plt.yticks(fontsize=15)
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.violinplot(x='general_cat',data=df)
#plt.ylim(-30, 100)
#plt.xlim(0,13)
plt.xticks(fontsize=15,style='oblique')
plt.yticks(fontsize=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-618a5099cc2c> in <module>()
#       1 plt.figure(figsize=(20, 10))
# ----> 2 sns.violinplot(x='general_cat',data=df)
#       3 #plt.ylim(-30, 100)
#       4 #plt.xlim(0,13)
#       5 plt.xticks(fontsize=15,style='oblique')
#
# C:\Python27\lib\site-packages\seaborn\categorical.pyc in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2345                              bw, cut, scale, scale_hue, gridsize,
#    2346                              width, inner, split, orient, linewidth,
# -> 2347                              color, palette, saturation)
#    2348
#    2349     if ax is None:
#
# ...

# %%
womenData.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-2f8d2e1c05d7> in <module>()
# ----> 1 womenData.info()
#
# NameError: name 'womenData' is not defined

# %%
dataMen.boxplot('price',by='brand_name')
plt.show()

# %%
plt.figure(figsize=(20, 10))
#sns.violinplot(x='general_cat',data=df)
dataMen.boxplot('price',by='brand_name')
plt.show()
plt.ylim(-30, 400)
#plt.xlim(0,13)
# Out:
# (-30, 400)

# %%
df
# Out:
#         train_id                                      name  item_condition_id  \
# 0              0       MLB Cincinnati Reds T Shirt Size XL                  3
# 1              1          Razer BlackWidow Chroma Keyboard                  3
# 2              2                            AVA-VIV Blouse                  1
# 3              3                     Leather Horse Statues                  1
# 4              4                      24K GOLD plated rose                  1
# 5              5          Bundled items requested for Ruie                  3
# 6              6        Acacia pacific tides santorini top                  3
# 7              7      Girls cheer and tumbling bundle of 7                  3
# 8              8                     Girls Nike Pro shorts                  3
# 9              9    Porcelain clown doll checker pants VTG                  3
# 10            10                           Smashbox primer                  2
# ...

# %%
df=df.drop(category_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-eb25f97d2553> in <module>()
# ----> 1 df=df.drop(category_name)
#
# NameError: name 'category_name' is not defined

# %%
df=df.drop('category_name',axis=1)

# %%
df
# Out:
#         train_id                                      name  item_condition_id  \
# 0              0       MLB Cincinnati Reds T Shirt Size XL                  3
# 1              1          Razer BlackWidow Chroma Keyboard                  3
# 2              2                            AVA-VIV Blouse                  1
# 3              3                     Leather Horse Statues                  1
# 4              4                      24K GOLD plated rose                  1
# 5              5          Bundled items requested for Ruie                  3
# 6              6        Acacia pacific tides santorini top                  3
# 7              7      Girls cheer and tumbling bundle of 7                  3
# 8              8                     Girls Nike Pro shorts                  3
# 9              9    Porcelain clown doll checker pants VTG                  3
# 10            10                           Smashbox primer                  2
# ...

# %%
df.brand_name=df.brand_name.fillna('no brand')

# %%
df
# Out:
#         train_id                                      name  item_condition_id  \
# 0              0       MLB Cincinnati Reds T Shirt Size XL                  3
# 1              1          Razer BlackWidow Chroma Keyboard                  3
# 2              2                            AVA-VIV Blouse                  1
# 3              3                     Leather Horse Statues                  1
# 4              4                      24K GOLD plated rose                  1
# 5              5          Bundled items requested for Ruie                  3
# 6              6        Acacia pacific tides santorini top                  3
# 7              7      Girls cheer and tumbling bundle of 7                  3
# 8              8                     Girls Nike Pro shorts                  3
# 9              9    Porcelain clown doll checker pants VTG                  3
# 10            10                           Smashbox primer                  2
# ...

# %%
df.item_description=df.item_description.fillna('No description yet')

# %%
df.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# train_id             0
# name                 0
# item_condition_id    0
# brand_name           0
# price                0
# shipping             0
# item_description     0
# general_cat          0
# sub_cat1             0
# sub_cat2             0
# dtype: int64

# %%
df
# Out:
#         train_id                                      name  item_condition_id  \
# 0              0       MLB Cincinnati Reds T Shirt Size XL                  3
# 1              1          Razer BlackWidow Chroma Keyboard                  3
# 2              2                            AVA-VIV Blouse                  1
# 3              3                     Leather Horse Statues                  1
# 4              4                      24K GOLD plated rose                  1
# 5              5          Bundled items requested for Ruie                  3
# 6              6        Acacia pacific tides santorini top                  3
# 7              7      Girls cheer and tumbling bundle of 7                  3
# 8              8                     Girls Nike Pro shorts                  3
# 9              9    Porcelain clown doll checker pants VTG                  3
# 10            10                           Smashbox primer                  2
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
le.fit((df['name']))
df.name=le.transform(df['name']).round(0)

# %%
df
# Out:
#         train_id    name  item_condition_id         brand_name  price  \
# 0              0  270379                  3           no brand   10.0
# 1              1  381656                  3              Razer   52.0
# 2              2   38229                  1             Target   10.0
# 3              3  236684                  1           no brand   35.0
# 4              4   18725                  1           no brand   44.0
# 5              5  104804                  3           no brand   59.0
# 6              6   39252                  3    Acacia Swimwear   64.0
# 7              7  180828                  3              Soffe    6.0
# 8              8  180289                  3               Nike   19.0
# 9              9  368043                  3           no brand    8.0
# 10            10  410803                  2           Smashbox    8.0
# 11            11  325358                  1  Victoria's Secret   34.0
# ...

# %%
le.fit((df['brand_name']))
df.brand_name=le.transform(df['brand_name']).round(0)

# %%
df
# Out:
#         train_id    name  item_condition_id  brand_name  price  shipping  \
# 0              0  270379                  3        3735   10.0         1
# 1              1  381656                  3        2764   52.0         0
# 2              2   38229                  1        3254   10.0         1
# 3              3  236684                  1        3735   35.0         1
# 4              4   18725                  1        3735   44.0         0
# 5              5  104804                  3        3735   59.0         0
# 6              6   39252                  3          66   64.0         0
# 7              7  180828                  3        3083    6.0         1
# 8              8  180289                  3        2380   19.0         0
# 9              9  368043                  3        3735    8.0         0
# 10            10  410803                  2        3070    8.0         1
# 11            11  325358                  1        3510   34.0         0
# ...

# %%
le.fit((df['item_description']))
df.item_description=le.transform(df['item_description']).round(0)

# %%
df
# Out:
#         train_id    name  item_condition_id  brand_name  price  shipping  \
# 0              0  270379                  3        3735   10.0         1
# 1              1  381656                  3        2764   52.0         0
# 2              2   38229                  1        3254   10.0         1
# 3              3  236684                  1        3735   35.0         1
# 4              4   18725                  1        3735   44.0         0
# 5              5  104804                  3        3735   59.0         0
# 6              6   39252                  3          66   64.0         0
# 7              7  180828                  3        3083    6.0         1
# 8              8  180289                  3        2380   19.0         0
# 9              9  368043                  3        3735    8.0         0
# 10            10  410803                  2        3070    8.0         1
# 11            11  325358                  1        3510   34.0         0
# ...

# %%
df.item_description.value_counts()
# Out:
# 329225    33028
# 300153     1672
# 99111      1267
# 195024      503
# 201838      464
# 250311      382
# 297341      327
# 286384      325
# 316370      260
# 295722      233
# 493317      230
# 168849      228
# 119401      204
# 308985      188
# 400753      187
# 93407       178
# 63957       173
# 123491      162
# 128291      161
# 133722      151
# 183207      147
# 370692      138
# 399293      136
# 284148      133
# 333059      127
# 226860      122
# 113599      122
# 203484      119
# 227897      110
# 398250      107
#           ...
# 189711        1
# 191758        1
# 328691        1
# 343028        1
# 340981        1
# 338934        1
# 336887        1
# 351224        1
# 349177        1
# 347130        1
# 345083        1
# 359420        1
# 357373        1
# 355326        1
# 353279        1
# 171264        1
# 169217        1
# 167170        1
# 165123        1
# 179460        1
# 177413        1
# 175366        1
# 173319        1
# 187656        1
# ...

# %%
le.fit((df['general_cat']))
df.general_cat=le.transform(df['general_cat']).round(0)

# %%
df
# Out:
#         train_id    name  item_condition_id  brand_name  price  shipping  \
# 0              0  270379                  3        3735   10.0         1
# 1              1  381656                  3        2764   52.0         0
# 2              2   38229                  1        3254   10.0         1
# 3              3  236684                  1        3735   35.0         1
# 4              4   18725                  1        3735   44.0         0
# 5              5  104804                  3        3735   59.0         0
# 6              6   39252                  3          66   64.0         0
# 7              7  180828                  3        3083    6.0         1
# 8              8  180289                  3        2380   19.0         0
# 9              9  368043                  3        3735    8.0         0
# 10            10  410803                  2        3070    8.0         1
# 11            11  325358                  1        3510   34.0         0
# ...

# %%
le.fit((df['sub_cat1']))
df.sub_cat1=le.transform(df['sub_cat1']).round(0)

# %%
df
# Out:
#         train_id    name  item_condition_id  brand_name  price  shipping  \
# 0              0  270379                  3        3735   10.0         1
# 1              1  381656                  3        2764   52.0         0
# 2              2   38229                  1        3254   10.0         1
# 3              3  236684                  1        3735   35.0         1
# 4              4   18725                  1        3735   44.0         0
# 5              5  104804                  3        3735   59.0         0
# 6              6   39252                  3          66   64.0         0
# 7              7  180828                  3        3083    6.0         1
# 8              8  180289                  3        2380   19.0         0
# 9              9  368043                  3        3735    8.0         0
# 10            10  410803                  2        3070    8.0         1
# 11            11  325358                  1        3510   34.0         0
# ...

# %%
le.fit((df['sub_cat2']))
df.sub_cat2=le.transform(df['sub_cat2']).round(0)

# %%
df
# Out:
#         train_id    name  item_condition_id  brand_name  price  shipping  \
# 0              0  270379                  3        3735   10.0         1
# 1              1  381656                  3        2764   52.0         0
# 2              2   38229                  1        3254   10.0         1
# 3              3  236684                  1        3735   35.0         1
# 4              4   18725                  1        3735   44.0         0
# 5              5  104804                  3        3735   59.0         0
# 6              6   39252                  3          66   64.0         0
# 7              7  180828                  3        3083    6.0         1
# 8              8  180289                  3        2380   19.0         0
# 9              9  368043                  3        3735    8.0         0
# 10            10  410803                  2        3070    8.0         1
# 11            11  325358                  1        3510   34.0         0
# ...

# %%
df_train=df.copy()

# %%
df_train
# Out:
#         train_id    name  item_condition_id  brand_name  price  shipping  \
# 0              0  270379                  3        3735   10.0         1
# 1              1  381656                  3        2764   52.0         0
# 2              2   38229                  1        3254   10.0         1
# 3              3  236684                  1        3735   35.0         1
# 4              4   18725                  1        3735   44.0         0
# 5              5  104804                  3        3735   59.0         0
# 6              6   39252                  3          66   64.0         0
# 7              7  180828                  3        3083    6.0         1
# 8              8  180289                  3        2380   19.0         0
# 9              9  368043                  3        3735    8.0         0
# 10            10  410803                  2        3070    8.0         1
# 11            11  325358                  1        3510   34.0         0
# ...

# %%
df_train=df_train.drop('train_id')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-077f6a6abc08> in <module>()
# ----> 1 df_train=df_train.drop('train_id')
#
# C:\Python27\lib\site-packages\pandas\core\generic.pyc in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# C:\Python27\lib\site-packages\pandas\core\indexes\base.pyc in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
#    3625             indexer = indexer[~mask]
# ...

# %%
df_train=df_train.drop('train_id',axis=1)

# %%
df_train
# Out:
#           name  item_condition_id  brand_name  price  shipping  \
# 0       270379                  3        3735   10.0         1
# 1       381656                  3        2764   52.0         0
# 2        38229                  1        3254   10.0         1
# 3       236684                  1        3735   35.0         1
# 4        18725                  1        3735   44.0         0
# 5       104804                  3        3735   59.0         0
# 6        39252                  3          66   64.0         0
# 7       180828                  3        3083    6.0         1
# 8       180289                  3        2380   19.0         0
# 9       368043                  3        3735    8.0         0
# 10      410803                  2        3070    8.0         1
# 11      325358                  1        3510   34.0         0
# 12       80702                  2        3743   16.0         0
# 13      402000                  1        2965    4.0         1
# ...

# %%
train_price=df_train.price

# %%
train_price
# Out:
# 0          10.0
# 1          52.0
# 2          10.0
# 3          35.0
# 4          44.0
# 5          59.0
# 6          64.0
# 7           6.0
# 8          19.0
# 9           8.0
# 10          8.0
# 11         34.0
# 12         16.0
# 13          4.0
# 14         43.0
# 15         11.0
# 16          6.0
# 17         29.0
# 18         25.0
# 19         27.0
# 20         13.0
# 21         20.0
# 22        386.0
# 23          8.0
# 24         10.0
# 25         66.0
# 26         13.0
# 27         24.0
# 28          5.0
# 29         16.0
#           ...
# 593346      8.0
# 593347     64.0
# 593348      5.0
# 593349     21.0
# 593350     10.0
# 593351     20.0
# 593352     33.0
# 593353     15.0
# 593354      7.0
# 593355      9.0
# 593356     44.0
# 593357     40.0
# 593358      7.0
# 593359      6.0
# 593360     17.0
# 593361     12.0
# 593362     12.0
# 593363     23.0
# 593364     24.0
# 593365     15.0
# 593366      7.0
# 593367     17.0
# 593368     38.0
# 593369      8.0
# ...

# %%
df_train.drop('price',axis=1)
# Out:
#           name  item_condition_id  brand_name  shipping  item_description  \
# 0       270379                  3        3735         1            329225
# 1       381656                  3        2764         0            445446
# 2        38229                  1        3254         1             47349
# 3       236684                  1        3735         1            319293
# 4        18725                  1        3735         0            149924
# 5       104804                  3        3735         0             69459
# 6        39252                  3          66         0            401473
# 7       180828                  3        3083         1            499987
# 8       180289                  3        2380         0            192793
# 9       368043                  3        3735         0            223263
# 10      410803                  2        3070         1             10511
# 11      325358                  1        3510         0              2334
# ...

# %%
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import Imputer
scaler = preprocessing.StandardScaler().fit(df_train[['name','brand_name','item_description','general_cat','sub_cat1','sub_cat2']])

# %%
scaler.mean_
scaler.scale_
# Out:
# array([  1.49043653e+05,   1.16557901e+03,   1.47020557e+05,
#          3.98926185e+00,   3.55815188e+01,   2.40126267e+02])

# %%
New_scaled =  scaler.transform(df_train[['name','brand_name','item_description','general_cat','sub_cat1','sub_cat2']]).round(4)

# %%
New_scaled
# Out:
# array([[ 0.0651,  0.8371,  0.4365, -0.2958,  1.0774,  1.2677],
#        [ 0.8117,  0.004 ,  1.227 , -1.2985, -0.9742, -0.902 ],
#        [-1.4925,  0.4244, -1.4807,  0.9576,  1.1055, -1.3725],
#        ...,
#        [ 0.6812,  0.8371,  0.432 , -1.2985,  1.246 , -0.4022],
#        [ 1.0539,  0.8371, -1.5162,  0.9576,  1.3304,  0.997 ],
#        [ 1.3419,  0.6441, -1.1837,  0.9576, -1.6768,  1.1095]])

# %%
New_scaled[:,0]
# Out:
# array([ 0.0651,  0.8117, -1.4925, ...,  0.6812,  1.0539,  1.3419])

# %%
df_train_processed=df_train.copy()

# %%
df_train_processed
# Out:
#           name  item_condition_id  brand_name  price  shipping  \
# 0       270379                  3        3735   10.0         1
# 1       381656                  3        2764   52.0         0
# 2        38229                  1        3254   10.0         1
# 3       236684                  1        3735   35.0         1
# 4        18725                  1        3735   44.0         0
# 5       104804                  3        3735   59.0         0
# 6        39252                  3          66   64.0         0
# 7       180828                  3        3083    6.0         1
# 8       180289                  3        2380   19.0         0
# 9       368043                  3        3735    8.0         0
# 10      410803                  2        3070    8.0         1
# 11      325358                  1        3510   34.0         0
# 12       80702                  2        3743   16.0         0
# 13      402000                  1        2965    4.0         1
# ...

# %%
df_train_processed['name']=New_scaled[:,0]

# %%
df_train_processed
# Out:
#           name  item_condition_id  brand_name  price  shipping  \
# 0       0.0651                  3        3735   10.0         1
# 1       0.8117                  3        2764   52.0         0
# 2      -1.4925                  1        3254   10.0         1
# 3      -0.1610                  1        3735   35.0         1
# 4      -1.6234                  1        3735   44.0         0
# 5      -1.0458                  3        3735   59.0         0
# 6      -1.4857                  3          66   64.0         0
# 7      -0.5358                  3        3083    6.0         1
# 8      -0.5394                  3        2380   19.0         0
# 9       0.7203                  3        3735    8.0         0
# 10      1.0072                  2        3070    8.0         1
# 11      0.4340                  1        3510   34.0         0
# 12     -1.2076                  2        3743   16.0         0
# 13      0.9482                  1        2965    4.0         1
# ...

# %%
df_train_processed['brand_name']=New_scaled[:,1]

# %%
df_train_processed['item_description']=New_scaled[:,2]

# %%
df_train_processed['general_cat']=New_scaled[:,3]

# %%
df_train_processed['sub_cat1']=New_scaled[:,4]

# %%
df_train_processed['sub_cat2']=New_scaled[:,5]

# %%
df_train_processed
# Out:
#           name  item_condition_id  brand_name  price  shipping  \
# 0       0.0651                  3      0.8371   10.0         1
# 1       0.8117                  3      0.0040   52.0         0
# 2      -1.4925                  1      0.4244   10.0         1
# 3      -0.1610                  1      0.8371   35.0         1
# 4      -1.6234                  1      0.8371   44.0         0
# 5      -1.0458                  3      0.8371   59.0         0
# 6      -1.4857                  3     -2.3107   64.0         0
# 7      -0.5358                  3      0.2777    6.0         1
# 8      -0.5394                  3     -0.3254   19.0         0
# 9       0.7203                  3      0.8371    8.0         0
# 10      1.0072                  2      0.2666    8.0         1
# 11      0.4340                  1      0.6441   34.0         0
# 12     -1.2076                  2      0.8440   16.0         0
# 13      0.9482                  1      0.1765    4.0         1
# ...

# %%
df_train_processed_price=df_train_processed['price']

# %%
df_train_processed_price
# Out:
# 0          10.0
# 1          52.0
# 2          10.0
# 3          35.0
# 4          44.0
# 5          59.0
# 6          64.0
# 7           6.0
# 8          19.0
# 9           8.0
# 10          8.0
# 11         34.0
# 12         16.0
# 13          4.0
# 14         43.0
# 15         11.0
# 16          6.0
# 17         29.0
# 18         25.0
# 19         27.0
# 20         13.0
# 21         20.0
# 22        386.0
# 23          8.0
# 24         10.0
# 25         66.0
# 26         13.0
# 27         24.0
# 28          5.0
# 29         16.0
#           ...
# 593346      8.0
# 593347     64.0
# 593348      5.0
# 593349     21.0
# 593350     10.0
# 593351     20.0
# 593352     33.0
# 593353     15.0
# 593354      7.0
# 593355      9.0
# 593356     44.0
# 593357     40.0
# 593358      7.0
# 593359      6.0
# 593360     17.0
# 593361     12.0
# 593362     12.0
# 593363     23.0
# 593364     24.0
# 593365     15.0
# 593366      7.0
# 593367     17.0
# 593368     38.0
# 593369      8.0
# ...

# %%
df_train_processed=df_train_processed.drop('price',axis=1)

# %%
df_train_processed
# Out:
#           name  item_condition_id  brand_name  shipping  item_description  \
# 0       0.0651                  3      0.8371         1            0.4365
# 1       0.8117                  3      0.0040         0            1.2270
# 2      -1.4925                  1      0.4244         1           -1.4807
# 3      -0.1610                  1      0.8371         1            0.3690
# 4      -1.6234                  1      0.8371         0           -0.7830
# 5      -1.0458                  3      0.8371         0           -1.3303
# 6      -1.4857                  3     -2.3107         0            0.9280
# 7      -0.5358                  3      0.2777         1            1.5980
# 8      -0.5394                  3     -0.3254         0           -0.4914
# 9       0.7203                  3      0.8371         0           -0.2842
# 10      1.0072                  2      0.2666         1           -1.7313
# 11      0.4340                  1      0.6441         0           -1.7869
# ...

# %%
 df_train_processed_price
# Out:
# 0          10.0
# 1          52.0
# 2          10.0
# 3          35.0
# 4          44.0
# 5          59.0
# 6          64.0
# 7           6.0
# 8          19.0
# 9           8.0
# 10          8.0
# 11         34.0
# 12         16.0
# 13          4.0
# 14         43.0
# 15         11.0
# 16          6.0
# 17         29.0
# 18         25.0
# 19         27.0
# 20         13.0
# 21         20.0
# 22        386.0
# 23          8.0
# 24         10.0
# 25         66.0
# 26         13.0
# 27         24.0
# 28          5.0
# 29         16.0
#           ...
# 593346      8.0
# 593347     64.0
# 593348      5.0
# 593349     21.0
# 593350     10.0
# 593351     20.0
# 593352     33.0
# 593353     15.0
# 593354      7.0
# 593355      9.0
# 593356     44.0
# 593357     40.0
# 593358      7.0
# 593359      6.0
# 593360     17.0
# 593361     12.0
# 593362     12.0
# 593363     23.0
# 593364     24.0
# 593365     15.0
# 593366      7.0
# 593367     17.0
# 593368     38.0
# 593369      8.0
# ...

# %%
frames
# Out:
# [          name  item_condition_id  brand_name  shipping  item_description  \
#  0       0.0651                  3      0.8371         1            0.4365
#  1       0.8117                  3      0.0040         0            1.2270
#  2      -1.4925                  1      0.4244         1           -1.4807
#  3      -0.1610                  1      0.8371         1            0.3690
#  4      -1.6234                  1      0.8371         0           -0.7830
#  5      -1.0458                  3      0.8371         0           -1.3303
#  6      -1.4857                  3     -2.3107         0            0.9280
#  7      -0.5358                  3      0.2777         1            1.5980
#  8      -0.5394                  3     -0.3254         0           -0.4914
#  9       0.7203                  3      0.8371         0           -0.2842
#  10      1.0072                  2      0.2666         1           -1.7313
# ...

# %%
result=pd.concat(df_train_processed,df_train_processed_price)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-137-91bb29f0063f> in <module>()
# ----> 1 result=pd.concat(df_train_processed,df_train_processed_price)
#
# C:\Python27\lib\site-packages\pandas\core\reshape\concat.pyc in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     204                        keys=keys, levels=levels, names=names,
#     205                        verify_integrity=verify_integrity,
# --> 206                        copy=copy)
#     207     return op.get_result()
#     208
#
# C:\Python27\lib\site-packages\pandas\core\reshape\concat.pyc in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy)
#     219             raise TypeError('first argument must be an iterable of pandas '
# ...

# %%
result=pd.concat(df_train_processed,df_train_processed_price,axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-138-383f4f695733> in <module>()
# ----> 1 result=pd.concat(df_train_processed,df_train_processed_price,axis=1)
#
# TypeError: concat() got multiple values for keyword argument 'axis'

# %%
df_train_processed.join(df_train_processed_price)
# Out:
#           name  item_condition_id  brand_name  shipping  item_description  \
# 0       0.0651                  3      0.8371         1            0.4365
# 1       0.8117                  3      0.0040         0            1.2270
# 2      -1.4925                  1      0.4244         1           -1.4807
# 3      -0.1610                  1      0.8371         1            0.3690
# 4      -1.6234                  1      0.8371         0           -0.7830
# 5      -1.0458                  3      0.8371         0           -1.3303
# 6      -1.4857                  3     -2.3107         0            0.9280
# 7      -0.5358                  3      0.2777         1            1.5980
# 8      -0.5394                  3     -0.3254         0           -0.4914
# 9       0.7203                  3      0.8371         0           -0.2842
# 10      1.0072                  2      0.2666         1           -1.7313
# 11      0.4340                  1      0.6441         0           -1.7869
# ...

# %%
import numpy as np

# %%
from sklearn.metrics import median_absolute_error
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.neighbors import KNeighborsRegressor

# %%
X = np.array(df_train_processed.ix[:,0:7].values)
# Out:
# C:\Python27\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.

# %%
X
# Out:
# array([[  6.51000000e-02,   3.00000000e+00,   8.37100000e-01, ...,
#           4.36500000e-01,  -2.95800000e-01,   1.07740000e+00],
#        [  8.11700000e-01,   3.00000000e+00,   4.00000000e-03, ...,
#           1.22700000e+00,  -1.29850000e+00,  -9.74200000e-01],
#        [ -1.49250000e+00,   1.00000000e+00,   4.24400000e-01, ...,
#          -1.48070000e+00,   9.57600000e-01,   1.10550000e+00],
#        ...,
#        [  6.81200000e-01,   5.00000000e+00,   8.37100000e-01, ...,
#           4.32000000e-01,  -1.29850000e+00,   1.24600000e+00],
#        [  1.05390000e+00,   2.00000000e+00,   8.37100000e-01, ...,
#          -1.51620000e+00,   9.57600000e-01,   1.33040000e+00],
#        [  1.34190000e+00,   1.00000000e+00,   6.44100000e-01, ...,
#          -1.18370000e+00,   9.57600000e-01,  -1.67680000e+00]])

# %%
X = np.array(df_train_processed.ix[:,0:8].values)

# %%
X
# Out:
# array([[  6.51000000e-02,   3.00000000e+00,   8.37100000e-01, ...,
#          -2.95800000e-01,   1.07740000e+00,   1.26770000e+00],
#        [  8.11700000e-01,   3.00000000e+00,   4.00000000e-03, ...,
#          -1.29850000e+00,  -9.74200000e-01,  -9.02000000e-01],
#        [ -1.49250000e+00,   1.00000000e+00,   4.24400000e-01, ...,
#           9.57600000e-01,   1.10550000e+00,  -1.37250000e+00],
#        ...,
#        [  6.81200000e-01,   5.00000000e+00,   8.37100000e-01, ...,
#          -1.29850000e+00,   1.24600000e+00,  -4.02200000e-01],
#        [  1.05390000e+00,   2.00000000e+00,   8.37100000e-01, ...,
#           9.57600000e-01,   1.33040000e+00,   9.97000000e-01],
#        [  1.34190000e+00,   1.00000000e+00,   6.44100000e-01, ...,
#           9.57600000e-01,  -1.67680000e+00,   1.10950000e+00]])

# %%
Y = np.array(df_train_processed.ix[:,].values)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-146-f0a7ed13dbb2> in <module>()
# ----> 1 Y = np.array(df_train_processed.ix[:,8].values)
#
# C:\Python27\lib\site-packages\pandas\core\indexing.pyc in __getitem__(self, key)
#     116                 pass
#     117
# --> 118             return self._getitem_tuple(key)
#     119         else:
#     120             key = com._apply_if_callable(key, self.obj)
#
# C:\Python27\lib\site-packages\pandas\core\indexing.pyc in _getitem_tuple(self, tup)
#     834     def _getitem_tuple(self, tup):
#     835         try:
# --> 836             return self._getitem_lowerdim(tup)
#     837         except IndexingError:
#     838             pass
#
# C:\Python27\lib\site-packages\pandas\core\indexing.pyc in _getitem_lowerdim(self, tup)
#     965         for i, key in enumerate(tup):
# ...

# %%
df_train_processed
# Out:
#           name  item_condition_id  brand_name  shipping  item_description  \
# 0       0.0651                  3      0.8371         1            0.4365
# 1       0.8117                  3      0.0040         0            1.2270
# 2      -1.4925                  1      0.4244         1           -1.4807
# 3      -0.1610                  1      0.8371         1            0.3690
# 4      -1.6234                  1      0.8371         0           -0.7830
# 5      -1.0458                  3      0.8371         0           -1.3303
# 6      -1.4857                  3     -2.3107         0            0.9280
# 7      -0.5358                  3      0.2777         1            1.5980
# 8      -0.5394                  3     -0.3254         0           -0.4914
# 9       0.7203                  3      0.8371         0           -0.2842
# 10      1.0072                  2      0.2666         1           -1.7313
# 11      0.4340                  1      0.6441         0           -1.7869
# ...

# %%
df_train_processed=df_train_processed.join(df_train_processed_price)

# %%
df_train_processed
# Out:
#           name  item_condition_id  brand_name  shipping  item_description  \
# 0       0.0651                  3      0.8371         1            0.4365
# 1       0.8117                  3      0.0040         0            1.2270
# 2      -1.4925                  1      0.4244         1           -1.4807
# 3      -0.1610                  1      0.8371         1            0.3690
# 4      -1.6234                  1      0.8371         0           -0.7830
# 5      -1.0458                  3      0.8371         0           -1.3303
# 6      -1.4857                  3     -2.3107         0            0.9280
# 7      -0.5358                  3      0.2777         1            1.5980
# 8      -0.5394                  3     -0.3254         0           -0.4914
# 9       0.7203                  3      0.8371         0           -0.2842
# 10      1.0072                  2      0.2666         1           -1.7313
# 11      0.4340                  1      0.6441         0           -1.7869
# ...

# %%
X
# Out:
# array([[  6.51000000e-02,   3.00000000e+00,   8.37100000e-01, ...,
#          -2.95800000e-01,   1.07740000e+00,   1.26770000e+00],
#        [  8.11700000e-01,   3.00000000e+00,   4.00000000e-03, ...,
#          -1.29850000e+00,  -9.74200000e-01,  -9.02000000e-01],
#        [ -1.49250000e+00,   1.00000000e+00,   4.24400000e-01, ...,
#           9.57600000e-01,   1.10550000e+00,  -1.37250000e+00],
#        ...,
#        [  6.81200000e-01,   5.00000000e+00,   8.37100000e-01, ...,
#          -1.29850000e+00,   1.24600000e+00,  -4.02200000e-01],
#        [  1.05390000e+00,   2.00000000e+00,   8.37100000e-01, ...,
#           9.57600000e-01,   1.33040000e+00,   9.97000000e-01],
#        [  1.34190000e+00,   1.00000000e+00,   6.44100000e-01, ...,
#           9.57600000e-01,  -1.67680000e+00,   1.10950000e+00]])

# %%
Y=np.array(df_train_processed.ix[:,8].values)
# Out:
# C:\Python27\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.

# %%
Y
# Out:
# array([ 10.,  52.,  10., ...,  20.,  18.,  32.])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
len(X_train)
# Out:
# 474700

# %%
len(X_test)
# Out:
# 118676

# %%
len(Y_train)
# Out:
# 474700

# %%
len(Y_test)
# Out:
# 118676

# %%
gbr = GradientBoostingRegressor(n_estimators=320,learning_rate =0.09, loss='huber',
                                min_samples_split= 4, max_depth=8,  
                                max_features=2)
gbr = gbr.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-161-a99b4265765c> in <module>()
#       2                                 min_samples_split= 4, max_depth=8,
#       3                                 max_features=2)
# ----> 4 gbr = gbr.fit(X_train, Y_train)
#
# C:\Python27\lib\site-packages\sklearn\ensemble\gradient_boosting.py in fit(self, X, y, sample_weight, monitor)
#    1026         # fit the boosting stages
#    1027         n_stages = self._fit_stages(X, y, y_pred, sample_weight, random_state,
# -> 1028                                     begin_at_stage, monitor, X_idx_sorted)
#    1029         # change shape of arrays after fit (early-stopping or additional ests)
#    1030         if n_stages != self.estimators_.shape[0]:
#
# ...

# %%
accuracy = gbr.score(X_test, Y_test)

# %%
accuracy

# %%
print accuracy

# %%
print(accuracy)

# %%
X_train

# %%
len(X_test)
# Out:
# 118676

# %%
gbr = GradientBoostingRegressor(n_estimators=20,learning_rate =0.09, loss='huber',
                                min_samples_split= 2, max_depth=1,  
                                max_features=2)
gbr = gbr.fit(X_train, Y_train)

# %%
len(X_test)
# Out:
# 118676

# %%
accuracy = gbr.score(X_test, Y_test)

# %%
len(X_test)
# Out:
# 118676

# %%
accuracy
# Out:
# -0.0065426012456890623

# %%
rfr = RandomForestRegressor(n_estimators=150,n_jobs=-1,min_samples_leaf=5, max_features=0.5)
rfr = rfr.fit(X_train, Y_train)
print("Random Forest Accuracy:", round((rfr.score(X_test, Y_test))*100,4), '%')
# Out:
# ('Random Forest Accuracy:', 36.3134, '%')

# %%
len(X_test)
# Out:
# 118676

# %%
Y_train
# Out:
# array([ 16.,  31.,  19., ...,  28.,  39.,   6.])

# %%
Y_test
# Out:
# array([  29.,    9.,   15., ...,   12.,  105.,    6.])

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
                 'n_estimators': [50,100,150,200,250],
                 'n_jobs':[-2,-1,1,2],
                'min_samples_leaf':[2,3,4,5,6,7],
                'max_depth': [1,2,3],
              'max_features':[0.5,1,1.5,2]
             }

rfr = RandomForestRegressor()
grid_rfr = GridSearchCV(rfr, param_grid, cv=10)
grid_rfr.fit(X_train, Y_train)
grid_rfr.cv_results_
print(grid_rfr.score(X_test, Y_test))
print("Best Parameters:")
print(grid_rfr. best_params_)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-179-d5c00856dfae> in <module>()
#       9 rfr = RandomForestRegressor()
#      10 grid_rfr = GridSearchCV(rfr, param_grid, cv=10)
# ---> 11 grid_rfr.fit(X_train, Y_train)
#      12 grid_rfr.cv_results_
#      13 print(grid_rfr.score(X_test, Y_test))
#
# C:\Python27\lib\site-packages\sklearn\model_selection\_search.pyc in fit(self, X, y, groups)
#     943             train/test set.
#     944         """
# --> 945         return self._fit(X, y, groups, ParameterGrid(self.param_grid))
#     946
#     947
#
# C:\Python27\lib\site-packages\sklearn\model_selection\_search.pyc in _fit(self, X, y, groups, parameter_iterable)
#     562                                   return_times=True, return_parameters=True,
#     563                                   error_score=self.error_score)
# ...

# %%
len(X_test)
# Out:
# 118676

# %%
param_grid = {
                 'n_estimators': [50,100,150,200,250],
                 'n_jobs':[-2,-1,1,2],
                'min_samples_leaf':[2,3,4,5,6,7],
                'max_depth': [1,2,3],
              'max_features':[0.5,1,1.5,2]
             }

rfr = RandomForestRegressor()
grid_rfr = GridSearchCV(rfr, param_grid, cv=10)
grid_rfr.fit(X_train, Y_train)
grid_rfr.cv_results_
print(grid_rfr.score(X_test, Y_test))
print("Best Parameters:")
print(grid_rfr. best_params_)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-181-d5c00856dfae> in <module>()
#       9 rfr = RandomForestRegressor()
#      10 grid_rfr = GridSearchCV(rfr, param_grid, cv=10)
# ---> 11 grid_rfr.fit(X_train, Y_train)
#      12 grid_rfr.cv_results_
#      13 print(grid_rfr.score(X_test, Y_test))
#
# C:\Python27\lib\site-packages\sklearn\model_selection\_search.pyc in fit(self, X, y, groups)
#     943             train/test set.
#     944         """
# --> 945         return self._fit(X, y, groups, ParameterGrid(self.param_grid))
#     946
#     947
#
# C:\Python27\lib\site-packages\sklearn\model_selection\_search.pyc in _fit(self, X, y, groups, parameter_iterable)
#     562                                   return_times=True, return_parameters=True,
#     563                                   error_score=self.error_score)
# ...

# %%
rfr = RandomForestRegressor(n_estimators=200,n_jobs=-1,min_samples_leaf=5, max_features=0.5)
rfr = rfr.fit(X_train, Y_train)
print("Random Forest Accuracy:", round((rfr.score(X_test, Y_test))*100,4), '%')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-182-ccaf898e8b40> in <module>()
#       1 rfr = RandomForestRegressor(n_estimators=200,n_jobs=-1,min_samples_leaf=5, max_features=0.5)
# ----> 2 rfr = rfr.fit(X_train, Y_train)
#       3 print("Random Forest Accuracy:", round((rfr.score(X_test, Y_test))*100,4), '%')
#
# C:\Python27\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     324                     t, self, X, y, sample_weight, i, len(trees),
#     325                     verbose=self.verbose, class_weight=self.class_weight)
# --> 326                 for i, t in enumerate(trees))
#     327
#     328             # Collect newly grown trees
#
# C:\Python27\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __call__(self, iterable)
#     766                 # consumption.
# ...

# %%
rfr = RandomForestRegressor(n_estimators=200,n_jobs=-1,min_samples_leaf=5, max_features=0.5)
rfr = rfr.fit(X_train, Y_train)
print("Random Forest Accuracy:", round((rfr.score(X_test, Y_test))*100,4), '%')
# Out:
# ('Random Forest Accuracy:', 36.1589, '%')

# %%
rfr = RandomForestRegressor(n_estimators=200,n_jobs=-1,min_samples_leaf=3, max_features=2)
rfr = rfr.fit(X_train, Y_train)
print("Random Forest Accuracy:", round((rfr.score(X_test, Y_test))*100,4), '%')
# Out:
# ('Random Forest Accuracy:', 34.3289, '%')

# %%
rfr = RandomForestRegressor(n_estimators=50,n_jobs=-1,min_samples_leaf=3, max_features=.5)
rfr = rfr.fit(X_train, Y_train)
print("Random Forest Accuracy:", round((rfr.score(X_test, Y_test))*100,4), '%')
# Out:
# ('Random Forest Accuracy:', 35.9284, '%')

# %%
rfr = RandomForestRegressor(n_estimators=300,n_jobs=-1,min_samples_leaf=5, max_features=0.5)
rfr = rfr.fit(X_train, Y_train)
print("Random Forest Accuracy:", round((rfr.score(X_test, Y_test))*100,4), '%')
# Out:
# ('Random Forest Accuracy:', 36.3269, '%')

# %%
rfr = RandomForestRegressor(n_estimators=500,n_jobs=-1,min_samples_leaf=5, max_features=0.5)
rfr = rfr.fit(X_train, Y_train)
print("Random Forest Accuracy:", round((rfr.score(X_test, Y_test))*100,4), '%')
# Out:
# ('Random Forest Accuracy:', 36.2853, '%')
